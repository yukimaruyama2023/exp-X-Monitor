# %%
# %load_ext autoreload
# %autoreload 2

from cpu_utilization_for_redis import make_plots
from cpu_utilization_for_redis import print_cpu_utilization_table

# BASE_DIR = "../data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251113-111829"
# BASE_DIR = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251128-151835"
BASE_DIR = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/redis/enable_mutilate-False/xdp_indirectcopy-True/20251207-195110"
results = make_plots(BASE_DIR, cpu_freq_hz=3_800_000_000, redis_nums=list(range(1, 13)))  # 3.8 GHz
print_cpu_utilization_table(results)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [info] Saved: /home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/redis/enable_mutilate-False/xdp_indirectcopy-True/20251207-195110/cpu_utilization_redis-user.pdf
# [info] Saved: /home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/redis/enable_mutilate-False/xdp_indirectcopy-True/20251207-195110/cpu_utilization_redis-user.png
# [info] Saved: /home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/redis/enable_mutilate-False/xdp_indirectcopy-True/20251207-195110/cpu_utilization_redis-kernel.pdf
# [info] Saved: /home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/redis/enable_mutilate-False/xdp_indirectcopy-True/20251207-195110/cpu_utilization_redis-kernel.png
# ===== CPU Utilization (Redis, metric=user) =====
#
# --- interval = 1 ---
# ...
