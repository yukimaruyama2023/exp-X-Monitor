# %%
# %load_ext autoreload
# %autoreload 2

# %%
from app_latency_100us import collect_latency99_12mcd
from throughput_100us import collect_throughput_12mcd
from latency_through_combined_100us import plot_latency_and_throughput_12mcd

base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/memcached/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251208-181111"
plot_latency_and_throughput_12mcd(base_dir)
# Out:
#   Cell In[2], line 3
#     from 100us_latency_through_combined import plot_latency_and_throughput_12mcd
#            ^
# SyntaxError: invalid decimal literal
