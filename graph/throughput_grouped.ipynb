# %%
# %load_ext autoreload
# %autoreload 2

import os, sys, importlib.util

print("CWD:", os.getcwd())
print("sys.path[0]:", sys.path[0])   
print("\n-- files in CWD --")
print("\n".join(sorted(os.listdir())))

print("\n-- presence checks --")
print("throughput_grouped.py exists:", os.path.exists("throughput_grouped.py"))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# CWD: /home/maruyama/workspace/exp-X-Monitor/graph
# sys.path[0]: /home/maruyama/workspace/exp-X-Monitor/graph
#
# -- files in CWD --
# __pycache__
# latency.ipynb
# latency.py
# only_latency.ipynb
# only_latency.py
# throughput.ipynb
# throughput.py
# throughput_grouped.ipynb
# throughput_grouped.py
#
# -- presence checks --
# throughput_grouped.py exists: True

# %%
import os
os.chdir("/home/maruyama/workspace/exp-X-Monitor/graph")

from throughput_grouped import plot_grouped

# base_dir = "../data/monitoring_throughput/strict-False/ntd_mcd_allcores-False/20251105-115302"
# base_dir = "../data/monitoring_throughput/strict-False/ntd_mcd_allcores-True/20251105-133356"
base_dir = "../data/monitoring_throughput/strict-False/ntd_mcd_allcores-True/20251105-181850/0"

for metric in ["kernel", "user"]:
    plot_grouped(base_dir, metric, nums=[1,5,10])

# %%
# %cd /home/maruyama/workspace/exp-X-Monitor/graph
from throughput_grouped import plot_grouped

base_dir = "../data/monitoring_throughput/strict-False/ntd_mcd_allcores-False/20251105-115302"
for metric in ["kernel", "user"]:
    plot_grouped(base_dir, metric, nums=[1,5,10])
# Out:
# /home/maruyama/workspace/exp-X-Monitor/graph
# /home/maruyama/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
