# %%
# %load_ext autoreload
# %autoreload 2

from app_latency_100us import (
    plot_latency99_12mcd,
    print_latency99_12mcd_means
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/memcached/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251208-181111"
# nums = list(range(1, 13))
# nums = [12]

# print_latency99_means(base_dir, nums)
# plot_grouped_latency99(base_dir, nums)


nums = [12]  # 12 instance だけなら

# print_latency99_means(base_dir, nums)
# plot_grouped_latency99(base_dir, nums)
plot_latency99_12mcd(base_dir)
print_latency99_12mcd_means(base_dir)
# Out:
# ===== 99th latency (ms): Means for user metrics (12 mcd, 100us) =====
# [ user   | No Monitoring ] mean=4.130 ms (std=0.051)
# [ user   | Netdata (100us) ] mean=4.716 ms (std=0.079)
# [ user   | X-Monitor (100us) ] mean=4.143 ms (std=0.052)
#
# ===== 99th latency (ms): Means for kernel metrics (12 mcd, 100us) =====
# [ kernel | No Monitoring ] mean=4.130 ms (std=0.051)
# [ kernel | Netdata (100us) ] mean=4.757 ms (std=0.089)
# [ kernel | X-Monitor (100us) ] mean=4.092 ms (std=0.067)
# ===== 99th latency (ms): Means for user metrics (12 mcd, 100us) =====
# [ user   | No Monitoring ] mean=4.130 ms (std=0.051)
# [ user   | Netdata (100us) ] mean=4.716 ms (std=0.079)
# [ user   | X-Monitor (100us) ] mean=4.143 ms (std=0.052)
#
# ===== 99th latency (ms): Means for kernel metrics (12 mcd, 100us) =====
# [ kernel | No Monitoring ] mean=4.130 ms (std=0.051)
# [ kernel | Netdata (100us) ] mean=4.757 ms (std=0.089)
# [ kernel | X-Monitor (100us) ] mean=4.092 ms (std=0.067)
