# %%
from only_latency import plot_latency

dir_ = "../data/monitoring_latency/strict-False/pin-netdata-core0/20251029-143342"
DATA_PATH = f"{dir}/001mcd/netdata-kernelmetrics-1mcd.csv"
Y_MAX = 10                      
SKIPROWS = 0
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from only_latency import plot_latency
#       3 dir_ = "../data/monitoring_latency/strict-False/pin-netdata-core0/20251029-143342"
#       4 DATA_PATH = f"{dir}/001mcd/netdata-kernelmetrics-1mcd.csv"
#
# ImportError: cannot import name 'plot_latency' from 'only_latency' (/home/maruyama/workspace/exp-X-Monitor/graph/only_latency.py)
