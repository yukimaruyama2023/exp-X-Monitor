# %%
# %load_ext autoreload
# %autoreload 2

from cpu_utilization import make_plots
from cpu_utilization import print_cpu_utilization_table

# BASE_DIR = "../data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251113-111829"
# BASE_DIR = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251128-151835"
BASE_DIR = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/memcached/enable_mutilate-False/xdp_indirectcopy-True/20251208-021330" # 12-08 現在ではこれを載せる． 151835 のやつは，kernel metrics 収集時に printk をしてしまっていた．
results = make_plots(BASE_DIR, cpu_freq_hz=3_800_000_000, mcd_nums=list(range(1, 13)))  # 3.8 GHz
print_cpu_utilization_table(results)

# make_plots(BASE_DIR, mcd_nums=list(range(1, 13)))  # 3.8 GHz
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [info] Saved: /home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251128-151835/cpu_utilization-user.pdf
# [info] Saved: /home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251128-151835/cpu_utilization-kernel.pdf
# ===== CPU Utilization (metric=user) =====
#
# --- interval = 1 ---
#   1 mcd : X-Monitor=0.000130 % , Netdata=3.2000 % (go.d=0.1500 %, stats=0.0000 %)
#   2 mcd : X-Monitor=0.000188 % , Netdata=3.5100 % (go.d=0.1800 %, stats=0.0000 %)
#   3 mcd : X-Monitor=0.000231 % , Netdata=3.7000 % (go.d=0.1800 %, stats=0.0000 %)
#   4 mcd : X-Monitor=0.000277 % , Netdata=4.4100 % (go.d=0.1800 %, stats=0.0000 %)
#   5 mcd : X-Monitor=0.000386 % , Netdata=3.3000 % (go.d=0.1500 %, stats=0.0000 %)
# ...
