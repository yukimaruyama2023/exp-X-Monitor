# %%
# %load_ext autoreload
# %autoreload 2

from cpu_utilization import make_plots

BASE_DIR = "../data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251113-111829"
make_plots(BASE_DIR, cpu_freq_hz=3_800_000_000, mcd_nums=list(range(1, 13)))  # 3.8 GHz
# make_plots(BASE_DIR, mcd_nums=list(range(1, 13)))  # 3.8 GHz
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 7
#       4 from cpu_utilization import make_plots
#       6 BASE_DIR = "../data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251113-111829"
# ----> 7 make_plots(BASE_DIR, save=True, cpu_freq_hz=3_800_000_000, mcd_nums=list(range(1, 13)))  # 3.8 GHz
#       8 # make_plots(BASE_DIR, mcd_nums=list(range(1, 13)))  # 3.8 GHz
#
# TypeError: make_plots() got an unexpected keyword argument 'save'
