# %%
# %load_ext autoreload
# %autoreload 2

from cpu_utilization import make_plots

BASE_DIR = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/20251109-030217"
make_plots(BASE_DIR, cpu_freq_hz=3_800_000_000)  # 3.8 GHz
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
