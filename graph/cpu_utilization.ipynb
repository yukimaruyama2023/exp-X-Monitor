# %%
# %load_ext autoreload
# %autoreload 2

from cpu_utilization import make_plots

# BASE_DIR = "../data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251113-111829"
BASE_DIR = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251128-151835"
make_plots(BASE_DIR, cpu_freq_hz=3_800_000_000, mcd_nums=list(range(1, 13)))  # 3.8 GHz
# make_plots(BASE_DIR, mcd_nums=list(range(1, 13)))  # 3.8 GHz
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [info] Saved: /home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251128-151835/cpu_utilization-user.png
# [info] Saved: /home/maruyama/workspace/exp-X-Monitor/data/monitoring_cpu_utilization/enable_mutilate-False/xdp_indirectcopy-True/20251128-151835/cpu_utilization-kernel.png
