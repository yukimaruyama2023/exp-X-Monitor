# %%
# %load_ext autoreload
# %autoreload 2

from throughput import plot_grouped_both
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# base_dir = "../data/monitoring_throughput/strict-False/ntd_mcd_allcores-False/20251106-022401"
# base_dir = "../data/monitoring_throughput/strict-False/ntd_mcd_allcores-True/20251105-181850" # False, True
base_dir = "../data/monitoring_throughput/strict-True/ntd_mcd_allcores-False/20251109-202235" # True, Flase

nums = [1, 5, 10] 

plot_grouped_both(base_dir, nums=nums)
