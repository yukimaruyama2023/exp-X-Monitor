# %%
# %load_ext autoreload
# %autoreload 2

from throughput import plot_grouped_both
from throughput import print_throughput_means
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# base_dir = "../data/monitoring_throughput/strict-False/ntd_mcd_allcores-False/20251106-022401"
# base_dir = "../data/monitoring_throughput/strict-False/ntd_mcd_allcores-True/20251105-181850" # False, True
# base_dir = "../data/monitoring_throughput/strict-True/ntd_mcd_allcores-False/20251109-202235" # True, Flase
# base_dir = "../data/monitoring_throughput/strict-True/ntd_mcd_allcores-True/20251110-191159" # True, True
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_allcores/prioritized-False/xdp_indirectcopy-True/20251120-223234" # かなり良い感じだが，recv 後に interval 待っている．
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_allcores/prioritized-False/xdp_indirectcopy-True/20251121-210405"

# base_dir = "../data/monitoring_throughput/strict-True/all_runs_in_allcores/20251111-195451" # all_runs_in_allcores
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_allcores/prioritized-False/xdp_indirectcopy-True/20251123-135013" # [test] 方法 1, -c 3
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_allcores/prioritized-False/xdp_indirectcopy-True/20251123-152036" # [test] 方法 1, -u 1, -c 1
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_allcores/prioritized-False/xdp_indirectcopy-True/20251123-202455" # [test] 方法 1, -u 0, -c 30
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_allcores/prioritized-False/xdp_indirectcopy-True/20251124-005032" # [test] 方法 1, --recoreds 10, -u 0, -c 1
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_allcores/prioritized-False/xdp_indirectcopy-True/20251124-023543" # [test] 方法 1, --records 50,000,000, -u 0, -c 1
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251125-190127" # pin core 5 for stats. w/o interrupts isolation
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251126-155750"   # 上のに加え，interrupt が core 0-4 に入るようにしている．
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251126-172057" # 二つ上と同じ configuration のはず, 11 % ぐらいの差があるのは同じだが，base が低い
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251203-133342" # interval 0.002
base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251126-214004" # 二つ上のと同じ，1-12 mcd で実験している． 12-03 現在では，これを論文に載せる
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/memcached/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251208-181111" # interval 0.0001


# nums = [12] 
# nums = [1, 5, 6, 10, 12] 
nums = list(range(1,13))
# figsize = (10,7) # default is (10, 7)
# figsize = (15,7) # default is (10, 7)

plot_grouped_both(base_dir, nums=nums)  
print_throughput_means(base_dir, nums=nums)
# Out:
# ===== Kernel metrics: Throughput Means (K ops/sec) =====
#
# [ No Monitoring ]
#   1 mcd : 0.000
#   2 mcd : 0.000
#   3 mcd : 0.000
#   4 mcd : 0.000
#   5 mcd : 0.000
#   6 mcd : 0.000
#   7 mcd : 0.000
#   8 mcd : 0.000
#   9 mcd : 0.000
#   10 mcd : 0.000
#   11 mcd : 0.000
#   12 mcd : 790.158
#
# [ Netdata (1000ms) ]
#   1 mcd : 0.000
#   2 mcd : 0.000
#   3 mcd : 0.000
#   4 mcd : 0.000
#   5 mcd : 0.000
#   6 mcd : 0.000
#   7 mcd : 0.000
#   8 mcd : 0.000
#   9 mcd : 0.000
#   10 mcd : 0.000
#   11 mcd : 0.000
#   12 mcd : 0.000
#
# [ Netdata (500ms) ]
#   1 mcd : 0.000
#   2 mcd : 0.000
#   3 mcd : 0.000
#   4 mcd : 0.000
#   5 mcd : 0.000
#   6 mcd : 0.000
#   7 mcd : 0.000
#   8 mcd : 0.000
#   9 mcd : 0.000
#   10 mcd : 0.000
#   11 mcd : 0.000
#   12 mcd : 0.000
#
# [ Netdata (1ms) ]
#   1 mcd : 0.000
#   2 mcd : 0.000
#   3 mcd : 0.000
#   4 mcd : 0.000
#   5 mcd : 0.000
#   6 mcd : 0.000
#   7 mcd : 0.000
#   8 mcd : 0.000
#   9 mcd : 0.000
#   10 mcd : 0.000
# ...
