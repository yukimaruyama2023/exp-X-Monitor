# %%
# %load_ext autoreload
# %autoreload 2

from throughput_100us import plot_throughput_12mcd, print_throughput_12mcd_means
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/memcached/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251208-181111"

# nums = list(range(1, 13))
nums = [12]
run_ids = [0, 1, 2, 3, 4]    

plot_throughput_12mcd(base_dir)
print_throughput_12mcd_means(base_dir)
# Out:
# ===== Raw QPS Means over runs (n=12) =====
# no_mon      : 790158.200
# net_kernel  : 724134.060
# net_user    : 713017.500
# xmon_kernel : 783769.960
# xmon_user   : 783585.960
