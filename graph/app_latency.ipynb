# %%
# %load_ext autoreload
# %autoreload 2

from app_latency import plot_grouped_latency99
from app_latency import print_latency99_means
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251126-214004" # 二つ上のと同じ，1-12 mcd で実験している．

nums = list(range(1, 13))
plot_grouped_latency99(base_dir, nums=nums)
print_latency99_means(base_dir, nums=nums)
# Out:
# ===== Plotting 99th latency for kernel metrics =====
# [kernel] No Monitoring: [0.19860000000000003, 0.24996000000000002, 0.27196, 0.34116, 0.36937999999999993, 0.57952, 1.3275200000000003, 1.58552, 1.91478, 2.5721600000000002, 3.28748, 4.04376] ms
# [kernel] Netdata (1000ms): [0.19482, 0.2587, 0.27342000000000005, 0.34476, 0.39117999999999997, 0.70436, 1.46926, 1.7845000000000002, 2.5790800000000003, 3.011, 3.97004, 4.19816] ms
# [kernel] X-Monitor (1000ms): [0.19663999999999998, 0.2612, 0.27198, 0.34246, 0.37242, 0.58266, 1.33058, 1.6124000000000003, 1.8955000000000002, 2.5581199999999997, 3.26914, 4.01054] ms
# [kernel] Netdata (500ms): [0.194, 0.26212, 0.27555999999999997, 0.34558, 0.39376000000000005, 0.75316, 1.47354, 1.81646, 2.57182, 3.134, 3.87748, 4.23092] ms
# [kernel] X-Monitor (500ms): [0.20035999999999995, 0.25952000000000003, 0.27366, 0.34307999999999994, 0.36936, 0.5901, 1.31574, 1.6017199999999998, 1.83872, 2.60154, 3.3944400000000003, 4.039440000000001] ms
# ...
