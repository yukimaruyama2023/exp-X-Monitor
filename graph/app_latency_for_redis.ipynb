# %%
# %load_ext autoreload
# %autoreload 2

from app_latency_for_redis import plot_grouped_both
from app_latency_for_redis import print_latency99_means
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/memcached/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251204-190028"
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251203-133342" # interval 0.002
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251126-214004" # 二つ上のと同じ，1-12 mcd で実験している． 12-03 現在では，これを論文に載せる
# base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/redis/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251205-181541"
base_dir = "/home/maruyama/workspace/exp-X-Monitor/data/monitoring_throughput/redis/strict-True/all_runs_in_0_4cores/prioritized-False/xdp_indirectcopy-True/20251206-162143" # 12-07 時点でこれで良さそう

# nums = [12] 
# nums = [1, 5, 6, 10, 12] 
nums = list(range(1,13))
# figsize = (10,7) # default is (10, 7)
# figsize = (15,7) # default is (10, 7)

plot_grouped_both(base_dir, nums=nums)  
print_latency99_means(base_dir, nums=nums)
# Out:
# ===== Kernel metrics: 99th latency (ms) =====
#
# [ No Monitoring ]
#   1 redis : 0.156 ms
#   2 redis : 0.166 ms
#   3 redis : 0.178 ms
#   4 redis : 0.191 ms
#   5 redis : 0.228 ms
#   6 redis : 0.391 ms
#   7 redis : 2.535 ms
#   8 redis : 4.079 ms
#   9 redis : 4.151 ms
#   10 redis : 4.179 ms
#   11 redis : 4.242 ms
#   12 redis : 6.012 ms
#
# [ Netdata (1000ms) ]
#   1 redis : 0.151 ms
#   2 redis : 0.162 ms
#   3 redis : 0.175 ms
#   4 redis : 0.191 ms
#   5 redis : 0.234 ms
#   6 redis : 0.370 ms
#   7 redis : 2.988 ms
#   8 redis : 4.131 ms
#   9 redis : 4.159 ms
#   10 redis : 4.198 ms
#   11 redis : 5.108 ms
#   12 redis : 7.276 ms
#
# [ X-Monitor (1000ms) ]
#   1 redis : 0.151 ms
#   2 redis : 0.171 ms
#   3 redis : 0.175 ms
#   4 redis : 0.191 ms
#   5 redis : 0.231 ms
#   6 redis : 0.391 ms
#   7 redis : 2.588 ms
#   8 redis : 4.099 ms
#   9 redis : 4.156 ms
#   10 redis : 4.175 ms
#   11 redis : 4.306 ms
#   12 redis : 5.882 ms
#
# [ Netdata (500ms) ]
# ...
